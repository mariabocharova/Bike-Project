# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
data = pd.read_csv('all_data_3.csv')

# %%
data['start_date'] = pd.to_datetime(data['start_date'])

data['month_year'] = data['start_date'].dt.strftime('%Y-%m')

# %%
dat_new = data.filter(['start_date','usertype', 'month_year', 'duration'], axis = 1)

# %%
#dat_new.to_csv(r'C:\Users\marii\OneDrive\Desktop\SCHOOL\CSE 696 Final Project\Main Data\data_new_3.csv')

# %%
df2 = data.groupby('start_date')['paleo_commuter'].apply(list)

# %%
plt.plot((data['start_date'].sample(n=50)), data['paleo_commuter'].sample(n=50))
plt.show()

# %%
data.set_index('start_date', inplace = True)
data.groupby('start_date')['paleo_commuter'].plot(legend = True)
# Out:
# start_date
# 2019-01-01    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-01-02    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-01-03    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-01-04    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-01-05    AxesSubplot(0.125,0.125;0.775x0.755)
#                               ...
# 2021-12-27    AxesSubplot(0.125,0.125;0.775x0.755)
# 2021-12-28    AxesSubplot(0.125,0.125;0.775x0.755)
# 2021-12-29    AxesSubplot(0.125,0.125;0.775x0.755)
# 2021-12-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2021-12-31    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: paleo_commuter, Length: 1096, dtype: object

# %%
grouped_data = data.groupby('start_date')

# %%
 jan = grouped_data.get_group('2019-01-01')

# %%
jan.head()
# Out:
#             duration    usertype    city  average_city_speed(mph)  \
# start_date
# 2019-01-01         6  Subscriber  Boston                       12
# 2019-01-01         6  Subscriber  Boston                       12
# 2019-01-01         5  Subscriber  Boston                       12
# 2019-01-01        39    Customer  Boston                       12
# 2019-01-01        33  Subscriber  Boston                       12
#
#             speed_min_mile  distance_traveled  paleo_commuter  vegan_commuter  \
# start_date
# 2019-01-01               5                1.2           224.4            66.6
# 2019-01-01               5                1.2           224.4            66.6
# 2019-01-01               5                1.0           187.0            55.5
# 2019-01-01               5                7.8          1458.6           432.9
# 2019-01-01               5                6.6          1234.2           366.3
#
#             regular_commuter  car_emission
# start_date
# ...

# %%
sns.kdeplot(data.paleo_commuter[data.city == 'Boston'], label='Boston')
sns.kdeplot(data.paleo_commuter[data.city == 'Austin'], label='Austin')
sns.kdeplot(data.paleo_commuter[data.city == 'LA'], label='LA')

plt.show()

# %%
sns.kdeplot(data.start_date[data.paleo_commuter].sample(n=50), label='paleo')
sns.kdeplot(data.start_date[data.vegan_commuter].sample(n=50), label='vegan')
sns.kdeplot(data.start_date[data.regular_commuter].sample(n=50), label='regular')
sns.kdeplot(data.start_date[data.car_emission].sample(n=50), label = 'car emission')

plt.xlabel('date')
plt.ylabel('type')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4212/1706958305.py in <module>
# ----> 1 sns.kdeplot(data.start_date[data.paleo_commuter].sample(n=50), label='paleo')
#       2 sns.kdeplot(data.start_date[data.vegan_commuter].sample(n=50), label='vegan')
#       3 sns.kdeplot(data.start_date[data.regular_commuter].sample(n=50), label='regular')
#       4 sns.kdeplot(data.start_date[data.car_emission].sample(n=50), label = 'car emission')
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     964             return self._get_values(key)
#     965
# --> 966         return self._get_with(key)
#     967
#     968     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#    1004
#    1005         # handle the dup indexing case GH#4246
# ...

# %%
data['start_date'] = pd.to_datetime(data['start_date'])

data['month_year'] = data['start_date'].dt.strftime('%Y-%m')

# %%
fig, ax = plt.subplots(figsize=(15,7))
data.groupby(['month_year','vegan_commuter']).count()['usertype'].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='month_year,vegan_commuter,paleo_commuter'>

# %%
data.groupby(['month_year','car_emission']).count()['vegan_commuter'].unstack().plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='month_year'>

# %%
data['start_date'] = pd.to_datetime(data['start_date'])
data['year'] = data['start_date'].dt.year

# %%
reduced_df = data.sample(frac=0.1)

# %%
my_col = ['#F4C671','#A971F4','#71F473']

# %%
reduced_df.plot(x= 'month_year', y = ['paleo_commuter', 'regular_commuter','vegan_commuter'], kind = 'line', figsize =(10,10), color = my_col)
# Out:
# <AxesSubplot:xlabel='month_year'>

# %%
sns.relplot(x = 'duration', y ='city', hue = 'month_year', data = reduced_df)

# %%
reduced_df.groupby('month_year')[['vegan_commuter', 'regular_commuter', 'paleo_commuter', 'car_emission']].mean().T.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
reduced_df.head()
# Out:
#          Unnamed: 0  duration    usertype         city start_date  \
# 1013089     1047307       118    Customer       Austin 2020-12-06
# 391139       425357         9  Subscriber  Los Angeles 2019-07-19
# 86861         96932         9  Subscriber       Boston 2019-10-22
# 763536       797754        10  Subscriber       Austin 2021-01-15
# 83549         93294        19    Customer       Boston 2019-10-11
#
#          average_city_speed(mph)  speed_min_mile  distance_traveled  \
# 1013089                       12               5               23.6
# 391139                        12               5                1.8
# 86861                         12               5                1.8
# 763536                        12               5                2.0
# 83549                         12               5                3.8
#
#          paleo_commuter  vegan_commuter  regular_commuter  car_emission  \
# 1013089          4413.2          1309.8            2124.0        9699.6
# ...

# %%
df = pd.read_csv('all_data_4.csv', header = 0, index_col=0, parse_dates = True, squeeze = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19040/51628790.py in <module>
# ----> 1 df = pd.read_csv('all_data_4.csv', header = 0, index_col=0, parse_dates = True, squeeze = True)
#
# NameError: name 'pd' is not defined

# %%
df_new = df.filter(['start_date', 'duration', 'distance_traveled'], axis = 1)

# %%
df_new.to_csv(r'C:\Users\marii\OneDrive\Desktop\SCHOOL\CSE 696 Final Project\Main Data\reduced_sample_df.csv')

# %%
d = pd.read_csv('reduced_sample_df.csv', header = 0, index_col = 0, parse_dates = True, squeeze = True)

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
import numpy as np
np.__version__
# Out:
# '1.20.3'

# %%
import st
math.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19172/3838383621.py in <module>
#       1 import math
# ----> 2 math.__version__
#
# AttributeError: module 'math' has no attribute '__version__'

# %%
# fit and evaluate an AR model
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
import numpy
from math import sqrt
 
# create a difference transform of the dataset
def difference(d):
    diff = list()
    for i in range(1, len(d)):
        value = d[i] - d[i - 1]
        diff.append(value)
        return numpy.array(diff)
def predict(coef, history):
    yhat = coef[0]
    for i in range(1, len(coef)):
        yhat += coef[i]*history[-i]
    return yhat

# %%
X = difference(d.values)
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:]

window = 6
model = AutoReg(train, lags =6)
model_fit = model.fit()
coef = model_fit.params

history = [train[i] for i in range(len(train))]
prediction=list()
for t in range(len(test)):
    yhat = predict(coef, history)
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
rsme = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' %rmse)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11556/1781097061.py in <module>
# ----> 1 X = difference(int(d.values))
#       2 size = int(len(X) * 0.66)
#       3 train, test = X[0:size], X[size:]
#       4
#       5 window = 6
#
# TypeError: only size-1 arrays can be converted to Python scalars
